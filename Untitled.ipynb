# %% [markdown]
# # MNIST Dataset Tutorial
#
# You need to have already installed `keras` and `tensorflow`.
#
# If you wish to use `tensorflow 1.x`, you need to ensure that you have `python <= 3.7` before you can install it like so:
# ``` bash
# pip install tensorflow==1.15.5  # Replace the version number with your own.
# pip install keras==1.2.2  # Again, replace the version number with your own.
# ```
# Otherwise, use the following bash commands to install the latest version of `tensorflow`:
# ```bash
# pip install tensorflow
# pip install keras
# ```

# %%
from keras.datasets import mnist

# %%
(train_X, train_y), (test_X, test_y) = mnist.load_data()
# Load training and test data from the MNIST dataset.
# Out:
# ...
# 11501568/11490434 [==============================] - 1s 0us/step

# %%
# Print the size of the loaded data.
print('X_train: ' + str(train_X.shape))
print('Y_train: ' + str(train_y.shape))
print('X_test:  '  + str(test_X.shape))
print('Y_test:  '  + str(test_y.shape))
# Out:
# X_train: (60000, 28, 28)
# Y_train: (60000,)
# X_test:  (10000, 28, 28)
# Y_test:  (10000,)

# %%
# %matplotlib inline
# Display the data in a matplotlib window
from matplotlib import pyplot
for i in range(9):
    pyplot.subplot(330 + 1 + i)
    # Convert the data of the first nine images to plot data.
    pyplot.imshow(train_X[i], cmap=pyplot.get_cmap('gray'))
    pyplot.show()
